# %%
# alamcena UN SOLO VALOR
A = 5 #int
a= "cinco" #str
b = True  #bool
c = 17,3 #double, float

# %%
Tipe()
Tape = (3,5,6,7) #izquierda= almacena ; Derecha= asigna.

# %%
# para almacenar MAS/MUCHOS VALORES
Tupla = B =(2,3,7) #Inmutable, es decir; no cambia
Lista = D = ["Juan", "Carlos"] # Es modificable
Diccionario = E = {SP:7} # derecha: valor, izquierda: clave
Diccionario {A :[1,2,3]
               B : (1,2)}

# %%
print("la variable es:", type(64))
print("la variable es:", type("Hola mundo"))
print("la variable es:", type  (True))
print("la variable es:", type(23.1))
# Out:
# la variable es: <class 'int'>
# la variable es: <class 'str'>
# la variable es: <class 'bool'>
# la variable es: <class 'float'>

# %% [markdown]
# #Variables que almacenan multiples datos

# %%
#declaracion o creacion de una Tupla
No_modificable = (1,2,3)
#mostar el tipo de la variable
print("la variable es de tipo: ", type(No_modificable))
# Out:
# la variable es de tipo:  <class 'tuple'>

# %%
#creacion de lista
Compras_modificable = ["arequipe", "leche", "ponque"]
#mosrar tipo de variable
print("la variable es de tipo: ", type (Compras_modificable))
# Out:
# la variable es de tipo:  <class 'list'>

# %%
#creacion de diccionario
Compras = {
    "Falda" : 1,
    "Blusa" : 2,
    "sandalia" : 3,
    "Chanclas" : 4,
    "Zapatilla" : 5,
    "Medias" : 6,
    "Pulsera" : 7,
    "Anillos" : 8
}
print("la variable es de tipo: ", type(Compras))
print(Compras)
# Out:
# la variable es de tipo:  <class 'dict'>
# {'Falda': 1, 'Blusa': 2, 'sandalia': 3, 'Chanclas': 4, 'Zapatilla': 5, 'Medias': 6, 'Pulsera': 7, 'Anillos': 8}

# %%
#Dataset
import pandas as pd #importando libreria de python
datos = {
    "Nombre": ['juan', 'maria', 'luis'],
    "Edades": [15,20,19],
    "Ciudades": ['Madrid', 'Cartagena', 'Bogota'],
    "Altura": [1.75, 1.60, 1.80],
    "ID": [105344673, 198765430, 1026578930],
    "Dep_fav": ['futbol', 'beisol', 'basketball'],
    "Profesion": ['Doctor', 'Docente', 'Ingeniero']

}
#crear un dataframe/set
dataframe = pd.DataFrame(datos)
#mostar el tipo de la variable
print("La variable es de tipo: ", type(dataframe))
print(dataframe)
# Out:
# La variable es de tipo:  <class 'pandas.core.frame.DataFrame'>
#   Nombre  Edades   Ciudades  Altura          ID     Dep_fav  Profesion
# 0   juan      15     Madrid    1.75   105344673      futbol     Doctor
# 1  maria      20  Cartagena    1.60   198765430      beisol    Docente
# 2   luis      19     Bogota    1.80  1026578930  basketball  Ingeniero
