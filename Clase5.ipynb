# %% [markdown]
# ## **Clase 5**
# ### Dar forma a las salidas de impresiones

# %%
## Forma clasica
AA = 13
BB = 'Trece'

print('Los valores son: ', AA, BB)
# Out:
# Los valores son:  13 Trece

# %%
CC = 14
DD = 'Postre'

print(f"El valor de la variable es: {CC} y el valor de la otra variable es: {DD}")
# Out:
# El valor de la variable es: 14 y el valor de la otra variable es: Postre

# %%
Nombre = 'Rosell, y soy un guia explorador de la tribu 54'
Edad = 18

print('Hola, mucho gusto mi nombre es {} y tengo {} años.'.format(Nombre, Edad))
# Out:
# Hola, mucho gusto mi nombre es Rosell, y soy un guia explorador de la tribu 54 y tengo 18 años.

# %%
# La 's' es 'string' y la 'd' es numero
Nombre = 'Nana'
Edad = 16

print('Hola, mucho gusto mi nombre es %s y tengo %d años.' % (Nombre, Edad))
# Out:
# Hola, mucho gusto mi nombre es Nana y tengo 16 años.

# %% [markdown]
# # Caracteres de escape

# %%
# Usando el \r ignora todo lo que este antes de '\r'
print("Me levante a desayunar, \rviaje hasta la Universidad y llegue tardee. ")
# Out:
# viaje hasta la Universidad y llegue tardee.

# %%
print("Me levante a desayunar,\rviaje hasta la Universidad y llegue \"tarde\". ")
# Out:
# viaje hasta la Universidad y llegue "tarde".

# %%
print("Nerieth\tDaniela\tRodriguez\tCastro")
# Out:
# Nerieth	Daniela	Rodriguez	Castro

# %%
print('El segundo semestre se acaba el 6 de Junio.\n Toca hacer un asadito.')
# Out:
# El segundo semestre se acaba el 6 de Junio.
#  Toca hacer un asadito.

# %%
print('En términos de programación,\r un \"algoritmo\" es una secuencia de pasos lógicos que permiten solucionar\t un problema.\n Por ejemplo: si perdemos el acceso a una cuenta nos dan una serie de pasos para poder identificarla y así recuperarla o borrarla,\n que desarrollándose de manera efectiva y lógica, lograrán un resultado determinado.')
# Out:
#  un "algoritmo" es una secuencia de pasos lógicos que permiten solucionar	 un problema.
#  Por ejemplo: si perdemos el acceso a una cuenta nos dan una serie de pasos para poder identificarla y así recuperarla o borrarla,
#  que desarrollándose de manera efectiva y lógica, lograrán un resultado determinado.

# %% [markdown]
# # Operadores matematicos y variables enteras y flotantes

# %%
Num1 = 30
Num2 = 10
#suma
suma = Num1 + Num2
#resta
resta = Num1 - Num2
print(f"El resultado de la suma es: {suma} y el tipo de la variable es: {type(suma)}")
print(f"El resultado de la resta entre el numero  {Num1} y el numero {Num2} \n es {resta} y el tipo de variable es: {type(resta)}")
# Out:
# El resultado de la suma es: 40 y el tipo de la variable es: <class 'int'>
# El resultado de la resta entre el numero  30 y el numero 10
#  es 20 y el tipo de variable es: <class 'int'>
